# %%
import pandas as pd
df = pd.read_csv('dataset_Facebook.csv', sep=';')
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
print(df['Type'].unique())
# Out:
# ['Photo' 'Status' 'Link' 'Video']

# %%
photo_subset = df[df['Type'] == 'Photo']
status_subset = df[df['Type'] == 'Status']
link_subset = df[df['Type'] == 'Link']
video_subset = df[df['Type'] == 'Video']

# %%
print(photo_subset)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
merged = pd.concat([photo_subset, video_subset])
print(merged)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
# ...

# %%
print(merged.shape)
# Out:
# (433, 19)

# %%
sorted_values = df.sort_values(by='Page total likes', ascending=False)
print(sorted_values)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 13             139441   Photo         2          12             5          3
# 1              139441  Status         2          12             3         10
# 0              139441   Photo         2          12             4          3
# 5              139441  Status         2          12             1          9
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
transposed = df.T
print(transposed.iloc[:3, :3])
# Out:
#                        0       1       2
# Page total likes  139441  139441  139441
# Type               Photo  Status   Photo
# Category               2       2       3

# %%
transposed.shape
# Out:
# (19, 500)

# %%
melted = pd.melt(df, id_vars=['Type', 'Page total likes', 'Post Month'], value_vars=['comment', 'like', 'share'], var_name='Engagement Type', value_name='Count')

# %%
print(melted)
# Out:
#         Type  Page total likes  Post Month Engagement Type  Count
# 0      Photo            139441          12         comment    4.0
# 1     Status            139441          12         comment    5.0
# 2      Photo            139441          12         comment    0.0
# 3      Photo            139441          12         comment   58.0
# 4      Photo            139441          12         comment   19.0
# ...      ...               ...         ...             ...    ...
# 1495   Photo             85093           1           share   26.0
# 1496   Photo             81370           1           share   22.0
# 1497   Photo             81370           1           share   18.0
# 1498   Photo             81370           1           share   38.0
# 1499   Photo             81370           1           share   28.0
#
# [1500 rows x 5 columns]

# %%
cast = melted.pivot_table(index=['Type', 'Page total likes', 'Post Month'], columns='Engagement Type', values='Count', aggfunc='sum')

# %%
print(cast)
# Out:
# Engagement Type                    comment   like  share
# Type  Page total likes Post Month
# Link  85979            1               0.0  128.0    9.0
#       86491            1               0.0   17.0    4.0
#       86909            1               1.0  101.0    5.0
#       91437            2               4.0  114.0   13.0
#       98195            3               2.0   32.0   15.0
# ...                                    ...    ...    ...
# Video 130791           7              18.0  315.0   76.0
#       134879           9               6.0  345.0  121.0
#       137893           11             19.0  548.0   97.0
#       138329           11              2.0   65.0   14.0
#       138895           12             18.0  143.0   13.0
#
# [149 rows x 3 columns]
