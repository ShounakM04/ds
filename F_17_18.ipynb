# %%
import pandas as pd
import numpy as np

df = pd.read_csv('heart.csv')
df.shape
# Out:
# (1025, 14)

# %%
df.hist(figsize=(10,12), edgecolor="black", bins=20)
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.histplot(data=df, x='chol', bins=20, edgecolor="black")
# Out:
# <Axes: xlabel='chol', ylabel='Count'>

# %%
plt.hist(df['chol'], edgecolor="black")
plt.xlabel("chol")
plt.ylabel("count")
plt.title("Count of Thalach")
plt.plot()
# Out:
# []

# %%
sns.stripplot(data = df, x='target', y='chol', color="purple", alpha=0.5)
# Out:
# <Axes: xlabel='target', ylabel='chol'>

# %%
sns.countplot(data=df, x='target', hue='cp')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
avg_chol = df.groupby('age')['thalach'].mean().reset_index()

sns.lineplot(data=avg_chol, x='age', y='thalach')
# Out:
# <Axes: xlabel='age', ylabel='thalach'>

# %%
plt.boxplot(df['chol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c7706d40590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c77066a55d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c7706d41290>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c77066a5090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c77066a6d90>],
#  'means': []}

# %%
avg_chol = df.groupby('age')['chol'].mean().reset_index()

sns.lineplot(data=avg_chol, x='age', y='chol')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.scatterplot(data=df, x='age', y='trestbps')
plt.title("Age vs Resting Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Resting Blood Pressure")
plt.grid(True)
plt.show()

# %%
df['target'].value_counts().plot.pie(autopct='%1.5f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['ca'].value_counts().plot.pie(autopct='%1.5f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(data=df['chol'])
sns.histplot(data=df['chol'])
sns.scatterplot(data=df['chol'])
# Out:
# <Axes: xlabel='chol', ylabel='chol'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a jointplot with scatter and histograms
sns.jointplot(x='age', y='thalach', data=df, kind='scatter')
# sns.boxplot(x='age', y='thalach', data=df)
# Add title for the plot
plt.suptitle("Scatter + Histogram: Age vs Max Heart Rate", y=1.02)

# Show plot
plt.show()
