# %%
import pandas as pd

df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
Iris_setosa = df[df['Species'] == 'Iris-setosa']
Iris_versicolor = df[df['Species'] == 'Iris-versicolor']
Iris_virginica = df[df['Species'] == 'Iris-virginica']

# %%
print("Iris-setosa shape: ", Iris_setosa.shape)
print("Iris-versicolor shape:", Iris_versicolor.shape)
print("Iris-virginica shape:", Iris_virginica.shape)
# Out:
# Iris-setosa shape:  (50, 6)
# Iris-versicolor shape: (50, 6)
# Iris-virginica shape: (50, 6)

# %%
merged = pd.concat([Iris_setosa, Iris_versicolor])
print(merged)
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# ...

# %%
print(merged.shape)
# Out:
# (100, 6)

# %%
sorted_values = df.sort_values(by='PetalLengthCm', ascending=False)
print(sorted_values)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 122  123            7.7           2.8            6.7           2.0
# 105  106            7.6           3.0            6.6           2.1
# 131  132            7.9           3.8            6.4           2.0
# ..   ...            ...           ...            ...           ...
# 41    42            4.5           2.3            1.3           0.3
# 35    36            5.0           3.2            1.2           0.2
# 14    15            5.8           4.0            1.2           0.2
# 13    14            4.3           3.0            1.1           0.1
# 22    23            4.6           3.6            1.0           0.2
#
#             Species
# 118  Iris-virginica
# 117  Iris-virginica
# 122  Iris-virginica
# 105  Iris-virginica
# 131  Iris-virginica
# ..              ...
# ...

# %%
transposed = df.T
print(transposed.shape)
print(transposed.iloc[:3, :3])
# Out:
# (6, 150)
#                  0    1    2
# Id               1    2    3
# SepalLengthCm  5.1  4.9  4.7
# SepalWidthCm   3.5  3.0  3.2

# %%
melted1 = pd.melt(df, id_vars=['Species', 'Id'], value_vars=['SepalLengthCm','SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], var_name='Metrics', value_name='Value')
print(melted1)
# Out:
#             Species   Id        Metrics  Value
# 0       Iris-setosa    1  SepalLengthCm    5.1
# 1       Iris-setosa    2  SepalLengthCm    4.9
# 2       Iris-setosa    3  SepalLengthCm    4.7
# 3       Iris-setosa    4  SepalLengthCm    4.6
# 4       Iris-setosa    5  SepalLengthCm    5.0
# ..              ...  ...            ...    ...
# 595  Iris-virginica  146   PetalWidthCm    2.3
# 596  Iris-virginica  147   PetalWidthCm    1.9
# 597  Iris-virginica  148   PetalWidthCm    2.0
# 598  Iris-virginica  149   PetalWidthCm    2.3
# 599  Iris-virginica  150   PetalWidthCm    1.8
#
# [600 rows x 4 columns]

# %%
wide1 = melted1.pivot_table(index=['Species', 'Id'], columns='Metrics' ,values='Value', aggfunc="sum")

# %%
print(wide1)
# Out:
# Metrics             PetalLengthCm  PetalWidthCm  SepalLengthCm  SepalWidthCm
# Species        Id
# Iris-setosa    1              1.4           0.2            5.1           3.5
#                2              1.4           0.2            4.9           3.0
#                3              1.3           0.2            4.7           3.2
#                4              1.5           0.2            4.6           3.1
#                5              1.4           0.2            5.0           3.6
# ...                           ...           ...            ...           ...
# Iris-virginica 146            5.2           2.3            6.7           3.0
#                147            5.0           1.9            6.3           2.5
#                148            5.2           2.0            6.5           3.0
#                149            5.4           2.3            6.2           3.4
#                150            5.1           1.8            5.9           3.0
#
# [150 rows x 4 columns]

# %%
melted = pd.melt(df, id_vars=['Species'], value_vars=['SepalLengthCm','SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], var_name='Metrics', value_name='Value')
print(melted)
