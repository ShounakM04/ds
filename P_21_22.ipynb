# %%
import pandas as pd
df = pd.read_csv('adult.csv')
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.hist(figsize=(10,12), bins=20, edgecolor="black", grid=False)
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'fnlwgt'}>],
#        [<Axes: title={'center': 'educational-num'}>,
#         <Axes: title={'center': 'capital-gain'}>],
#        [<Axes: title={'center': 'capital-loss'}>,
#         <Axes: title={'center': 'hours-per-week'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.histplot(data=df['hours-per-week'], bins=20, edgecolor="black")
plt.xlabel('hours-per-week')
plt.ylabel('count')
plt.title('Hours per week')
plt.show()

# %%
sns.histplot(data=df['age'], bins=20, edgecolor="black")
plt.xlabel('age')
plt.ylabel('count')
plt.title('Age of people')
plt.show()

# %%
sns.stripplot(data=df, x='relationship', y='age', jitter=True, alpha=0.6)
# Out:
# <Axes: xlabel='relationship', ylabel='age'>

# %%
sns.stripplot(data=df, x='income', y='age', jitter=True, alpha=0.5)
plt.title('Age distribution by Income Group')
plt.xlabel('Income')
plt.ylabel('Age')
plt.show()

# %%
sns.barplot(data=df, x='income', y='age', hue='gender')
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
avgdata = df.groupby('age')['hours-per-week'].mean().reset_index()
avgdata
# Out:
#     age  hours-per-week
# 0    17       21.137815
# 1    18       25.745940
# 2    19       30.560304
# 3    20       32.432165
# 4    21       34.252737
# ..  ...             ...
# 69   86       40.000000
# 70   87        7.000000
# 71   88       35.833333
# 72   89       30.000000
# 73   90       37.654545
#
# [74 rows x 2 columns]

# %%
sns.lineplot(data=avgdata, x='age', y='hours-per-week')
# Out:
# <Axes: xlabel='age', ylabel='hours-per-week'>

# %%
df['income'].value_counts().plot.pie(autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['race'].value_counts().plot.pie(autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['gender'].value_counts().plot.pie(autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(data=df, y='age')
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(data=df, y='educational-num')
# Out:
# <Axes: ylabel='educational-num'>

# %%
plt.figure(figsize=(15, 15))
sns.scatterplot(data=df, x='race', y='hours-per-week', hue='income')
# Out:
# <Axes: xlabel='race', ylabel='hours-per-week'>

# %%
sns.scatterplot(data=df, x='educational-num', y='hours-per-week', hue='income')
# Out:
# <Axes: xlabel='educational-num', ylabel='hours-per-week'>
