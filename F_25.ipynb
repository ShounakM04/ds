# %%
import pandas as pd

df = pd.read_csv('hepatitis.csv')
df
# Out:
#      Class  AGE  SEX STEROID  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER BIG  \
# 0        2   30    2       1           2       2       2        2         1
# 1        2   50    1       1           2       1       2        2         1
# 2        2   78    1       2           2       1       2        2         2
# 3        2   31    1       ?           1       2       2        2         2
# 4        2   34    1       2           2       2       2        2         2
# ..     ...  ...  ...     ...         ...     ...     ...      ...       ...
# 150      1   46    1       2           2       1       1        1         2
# 151      2   44    1       2           2       1       2        2         2
# 152      2   61    1       1           2       1       1        2         1
# 153      2   53    2       1           2       1       2        2         2
# 154      1   43    1       2           2       1       2        2         2
#
# ...

# %%
df['SEX'].unique()

male = df[df['SEX'] == 1]
female = df[df['SEX'] == 2]

# %%
print(male)
print(female)
# Out:
#      Class  AGE  SEX STEROID  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER BIG  \
# 1        2   50    1       1           2       1       2        2         1
# 2        2   78    1       2           2       1       2        2         2
# 3        2   31    1       ?           1       2       2        2         2
# 4        2   34    1       2           2       2       2        2         2
# 5        2   34    1       2           2       2       2        2         2
# ..     ...  ...  ...     ...         ...     ...     ...      ...       ...
# 149      2   36    1       2           2       2       2        2         2
# 150      1   46    1       2           2       1       1        1         2
# 151      2   44    1       2           2       1       2        2         2
# 152      2   61    1       1           2       1       1        2         1
# 154      1   43    1       2           2       1       2        2         2
#
# ...

# %%
merged = pd.concat([male, female])
merged.shape
# Out:
# (155, 20)

# %%
sorted = df.sort_values(by="SGOT", ascending=False)

# %%
print(sorted)
# Out:
#      Class  AGE  SEX STEROID  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER BIG  \
# 21       2   27    1       2           2       1       1        1         1
# 30       1   39    1       1           1       1       1        2         2
# 34       2   35    1       2           2       1       2        2         2
# 128      2   54    1       1           2       1       1        2         2
# 42       2   33    1       2           2       2       2        2         2
# ..     ...  ...  ...     ...         ...     ...     ...      ...       ...
# 38       2   42    1       1           2       2       2        2         2
# 96       2   30    1       1           2       1       1        2         2
# 85       2   28    1       1           2       1       1        1         2
# 121      2   20    1       1           2       1       1        1         2
# 90       2   50    2       1           2       1       2        2         1
#
# ...

# %%
for col in df.columns:
    df = df[df[col] != '?']

# %%
df.shape
# Out:
# (80, 20)

# %%
sorted1 = df.sort_values(by="PROTIME", ascending=False)
print(sorted1)
# Out:
#      Class  AGE  SEX STEROID  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER BIG  \
# 134      1   38    1       1           2       2       2        2         2
# 36       2   23    1       2           2       1       1        1         2
# 61       2   32    1       2           2       2       2        2         2
# 48       2   36    1       1           2       2       2        2         2
# 139      2   45    1       2           1       2       2        2         2
# ..     ...  ...  ...     ...         ...     ...     ...      ...       ...
# 25       2   27    1       1           2       1       1        2         2
# 81       2   36    1       2           2       2       2        2         2
# 82       2   30    1       1           2       2       2        2         2
# 96       2   30    1       1           2       1       1        2         2
# 130      2   54    1       2           2       2       2        2         2
#
# ...

# %%
transpose = df.T
print(transpose.shape)
# Out:
# (20, 80)

# %%
melted = pd.melt(df, id_vars=['AGE', 'SEX'], value_vars=['BILIRUBIN', 'ALK PHOSPHATE', 'SGOT', 'ALBUMIN', 'PROTIME'], var_name="Metrics", value_name="Value")
print(melted)
# Out:
#      AGE  SEX    Metrics Value
# 0     34    1  BILIRUBIN   0.9
# 1     39    1  BILIRUBIN   1.3
# 2     32    1  BILIRUBIN     1
# 3     41    1  BILIRUBIN   0.9
# 4     30    1  BILIRUBIN   2.2
# ..   ...  ...        ...   ...
# 395   45    1    PROTIME    85
# 396   49    1    PROTIME    35
# 397   31    1    PROTIME    54
# 398   53    2    PROTIME    48
# 399   43    1    PROTIME    42
#
# [400 rows x 4 columns]

# %%
cast = melted.pivot_table(index=['AGE', 'SEX'], columns='Metrics', values='Value', aggfunc='first')

# %%
print(cast.head())
# Out:
# Metrics ALBUMIN ALK PHOSPHATE BILIRUBIN PROTIME SGOT
# AGE SEX
# 20  1       2.9           160         1      23  118
# 22  2       4.2            48       0.9      64   20
# 23  1       4.1           194       1.3      90  150
# 25  1       4.5           181       1.3      57  181
#     2       4.3            45       0.4      70   18
